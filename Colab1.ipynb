# %% [markdown]
# <a href="https://colab.research.google.com/github/Shelmith-Kariuki/python/blob/master/Colab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
import calendar

# %%
import numpy as np
